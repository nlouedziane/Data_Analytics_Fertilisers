# %%
import pandas as pd

# %%
data = "../data/cereal-crop-yield-vs-fertilizer-application.csv"

# %%
data_df = pd.read_csv(data, encoding="ISO-8859-1")

data_df.head()
# Out:
#         Entity      Code  Year  \
# 0     Abkhazia  OWID_ABK  2015
# 1  Afghanistan       AFG  1961
# 2  Afghanistan       AFG  1962
# 3  Afghanistan       AFG  1963
# 4  Afghanistan       AFG  1964
#
#    Crops - Cereals, Total - 1717 - Yield - 5419 - hg/ha  \
# 0                                                NaN
# 1                                             1.1151
# 2                                             1.0790
# 3                                             0.9858
# 4                                             1.0828
#
#    Fertilizers indicators - Nutrient nitrogen N (total) - 3102 - Use per area of cropland - 5159 - kg/ha  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Continent
# 0      Asia
# 1       NaN
# 2       NaN
# 3       NaN
# ...

# %%
#dropping rows that does not contain any information
cleaned_data_df = data_df.dropna(how='any')

cleaned_data_df
# Out:
#                     Entity Code  Year  \
# 55             Afghanistan  AFG  2015
# 172                Albania  ALB  2015
# 230                Algeria  DZA  2015
# 348                 Angola  AGO  2015
# 403    Antigua and Barbuda  ATG  2015
# ...                    ...  ...   ...
# 11554            Venezuela  VEN  2015
# 11612              Vietnam  VNM  2015
# 11898                Yemen  YEM  2015
# 11990               Zambia  ZMB  2015
# 12049             Zimbabwe  ZWE  2015
#
#        Crops - Cereals, Total - 1717 - Yield - 5419 - hg/ha  \
# 55                                                2.1337
# 172                                               4.8738
# 230                                               1.4002
# 348                                               0.9825
# 403                                               1.5811
# ...                                                  ...
# 11554                                             3.5057
# ...
