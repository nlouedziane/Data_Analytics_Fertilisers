# %%
import pandas as pd

# %%
data = "../data/FertilizersProduct.csv"

# %%
data_df = pd.read_csv(data, encoding="ISO-8859-1")

data_df.head()
# Out:
#    Area Code         Area  Item Code                Item  Element Code  \
# 0          2  Afghanistan       4007  Ammonia, anhydrous          5610
# 1          2  Afghanistan       4007  Ammonia, anhydrous          5610
# 2          2  Afghanistan       4007  Ammonia, anhydrous          5610
# 3          2  Afghanistan       4007  Ammonia, anhydrous          5622
# 4          2  Afghanistan       4007  Ammonia, anhydrous          5622
#
#            Element  Year Code  Year      Unit  Value Flag
# 0  Import Quantity       2011  2011    tonnes   4.49    R
# 1  Import Quantity       2014  2014    tonnes   2.00    R
# 2  Import Quantity       2017  2017    tonnes   2.07    R
# 3     Import Value       2011  2011  1000 US$   2.69    R
# 4     Import Value       2014  2014  1000 US$   1.07    R

# %%
#checking that the number of rows match
data_df.count()
# Out:
# Area Code       164468
# Area            164468
# Item Code       164468
# Item            164468
# Element Code    164468
# Element         164468
# Year Code       164468
# Year            164468
# Unit            164468
# Value           164468
# Flag            164468
# dtype: int64

# %%
#removing rows that contain the unit tonnes to obtain data that contains only the price
clean_data_df = data_df[data_df["Unit"].str.contains("tonnes")==False]

clean_data_df
# Out:
#         Area Code         Area  Item Code  \
# 3               2  Afghanistan       4007
# 4               2  Afghanistan       4007
# 5               2  Afghanistan       4007
# 10              2  Afghanistan       4003
# 11              2  Afghanistan       4003
# ...           ...          ...        ...
# 164457        181     Zimbabwe       4006
# 164458        181     Zimbabwe       4006
# 164459        181     Zimbabwe       4006
# 164460        181     Zimbabwe       4006
# 164461        181     Zimbabwe       4006
#
#                                              Item  Element Code       Element  \
# 3                              Ammonia, anhydrous          5622  Import Value
# 4                              Ammonia, anhydrous          5622  Import Value
# 5                              Ammonia, anhydrous          5622  Import Value
# 10                          Ammonium nitrate (AN)          5622  Import Value
# ...
